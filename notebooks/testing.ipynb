# %%
import os 
os.getcwd()
# Out:
# '/home/kousik/ALL_OTHERS/standard-project/std-mlops-project'

# %%
import pandas as pd

# %%
df_train = pd.read_csv('../loan_data/loan_sanction_train.csv')

# %%
df_test = pd.read_csv('../loan_data/loan_sanction_test.csv')

# %%
df_test
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df_train
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df_train1 = df_train[:500]
df_train1
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 495  LP002586  Female     Yes          1      Graduate            No
# 496  LP002587    Male     Yes          0  Not Graduate            No
# 497  LP002588    Male     Yes          0      Graduate            No
# 498  LP002600    Male     Yes          1      Graduate           Yes
# 499  LP002602    Male      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df_train2 = df_train[500:]
df_train2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 500  LP002603  Female      No          0      Graduate            No
# 501  LP002606  Female      No          0      Graduate            No
# 502  LP002615    Male     Yes          2      Graduate            No
# 503  LP002618    Male     Yes          1  Not Graduate            No
# 504  LP002619    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# ## Insert into MongoDB

# %%
## At first, push df_train1 into MongoDB Atlas;   will retrain the ML algorithm with df_train2

# %%
! pip install pymongo

# %%
import pymongo

# %%
import getpass
PASSWORD = getpass.getpass()
# Out:
#  ········

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# uri = "mongodb+srv://kousik:<password>@try.4zwnsco.mongodb.net/?retryWrites=true&w=majority"
uri = f"mongodb+srv://kousik:{PASSWORD}@try.4zwnsco.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
# df_train1.to_dict()
#  df_train1.to_dict(orient='records')

# %%
db = client["mlops-project"]   # create database
collection = db['loan-data-main']

# %%
# Create a list of documents to insert
data_to_insert = df_train1.to_dict(orient='records')

# Insert the data into the collection
insert_ids = collection.insert_many(data_to_insert)
insert_ids

# %%
# insert_ids.inserted_ids

len(insert_ids.inserted_ids)
# Out:
# 500

# %% [markdown]
# ## Fetch from MongoDB

# %%
db = client["mlops-project"]   # create database
collection = db['loan-data-main']

# Convert the cursor to a Pandas DataFrame
df = pd.DataFrame(list(collection.find()))

# %%
df.drop(columns='_id',inplace=True)

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 495  LP002586  Female     Yes          1      Graduate            No
# 496  LP002587    Male     Yes          0  Not Graduate            No
# 497  LP002588    Male     Yes          0      Graduate            No
# 498  LP002600    Male     Yes          1      Graduate           Yes
# 499  LP002602    Male      No          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
